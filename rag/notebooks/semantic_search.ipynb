# %%
import os
from dotenv import load_dotenv

load_dotenv("../keys.env")
openai_api_key = os.getenv("GRAVY_LAB_OPENAI")

# %%
import faiss
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore

embeddings = OpenAIEmbeddings(api_key=openai_api_key, model="text-embedding-3-large")

"""
"hello world"라는 문장의 임베딩 길이를 제공하는 이유는 사용 중인 임베딩 모델이 반환하는 벡터의 차원을 알아내기 위한 방법임.

- faiss.IndexFlatIP : 내적 계산을 사용해 벡터간 유사성을 측정하는 인덱스
- faiss.IndexFlatL2 : L2 거리를 사용해 벡터간 유사성을 측정하는 인덱스
- faiss.IndexHNSWFlat : HNSW 알고리즘을 사용해 벡터간 유사성을 측정하는 인덱스
"""
index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))

vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
import mysql.connector
from mysql.connector import Error

def fetch_data_from_mysql():
    try:
        # MySQL 데이터베이스 연결
        connection = mysql.connector.connect(
            host="ls-662e72c42a259736c11c93759076a7409118e05a.cgzykv9hk4gr.ap-northeast-2.rds.amazonaws.com",
            port=3306,
            user="gravylab",
            password="glab0110!!",
            database="recruitdb"
        )

        if connection.is_connected():
            print("MySQL 데이터베이스에 성공적으로 연결되었습니다.")
            
            query = """
                SELECT * 
                FROM recruit
                WHERE platform_type IN ('WANTED');
            """
            cursor = connection.cursor(dictionary=True)
            cursor.execute(query)
            
            results = cursor.fetchall()

            cursor.close()
            connection.close()
            print("MySQL 연결이 닫혔습니다.")

            return results

    except Error as e:
        print(f"Error while connecting to MySQL: {e}")

# %%
dataset = fetch_data_from_mysql()
print(len(dataset))
# Out:
# MySQL 데이터베이스에 성공적으로 연결되었습니다.
# MySQL 연결이 닫혔습니다.
# 11115

# %%
from uuid import uuid4
from langchain_core.documents import Document

def dataset_to_documents(dataset, page_content_fields, metadata_fields):
    documents = []
    for data in dataset:
        page_content = ""
        for field in page_content_fields:
            page_content += f"{field}\n{data[field]}\n\n"

        metadata = {}
        for field in metadata_fields:
            metadata[field] = data[field]
            
        documents.append(Document(page_content=page_content, metadata=metadata, id=uuid4()))

    return documents

# %%
page_content_fields = ['title', 'description', 'tasks', 'requirements', 'points', 'work_description'] 
metadata_fields = ['career_type', 'career_min', 'career_max', 'work_type', 'education_type', 'workday_content', 'info_url']

documents = dataset_to_documents(dataset, page_content_fields, metadata_fields)
print(len(documents))
# Out:
# 11115

# %%
from random import randint

idx = randint(0, len(documents))
print(f"Index: {idx}")

sample_doc = documents[idx]
print(f"Page Content:\n{sample_doc.page_content}\n\n")
print(f"Metadata:\n{sample_doc.metadata}")
# Out:
# Index: 3761
# Page Content:
# title
# [Photoism][IPX-MD] MD 사업관리 담당자(책임매니저)
#
# description
# 서북의 핵심가치는 '누구나 즐길 수 있는 문화를 만드는 것'입니다.
# 새로운 문화를 만들고, 물리적이고 문화적인 장벽을 허무는 것, 우리가 가장 잘하는 것입니다.
# On-Offline을 잇는 허브가 되고자 하는 우리는 동종업계 성장률 1위를 자랑하고 있으며, 국내 뿐만 아니라 해외로 진출하여 현재 12개국 120여개 이상의 가맹점을 운영하고 있습니다.
# Global entertainment platform으로써 지금 이 순간도 성장하는 서북의 로켓에 탑승할 크루를 찾습니다 !
#
# 서북의 대표 프로덕트는 포토이즘으로 국내 450여 개, 글로벌 150여 개의 오프라인 매장을 운영 중이며 특히, 글로벌은 가파른 성장세를 보이고 있어 2025년부터는 글로벌을 중심으로 사업을 확장할 계획입니다.
#
# tasks
# • MD관련 사업성 검토 및 사업 전개, MD파트너십 계약 및 관리
# • 파트너사 협의를 통한 세일즈 확대 전략 수립 및 실행
# • 신규 비즈니스 모델(BM) 확장 제안, 시장 트렌드 분석 및 기회 발굴
#
# requirements
# • MD 사업 실행 및 관리 경험, 팝업스토어 전개 및 관리 경험
#   (최소 3년 이상, 5년 이상 우대)
# • 실무 경험을 바탕으로 하는 IP협업 및 엔터테인먼트 산업에 대한 높은 이해도
# • 신규 비즈니스 모델 개발 및 확장에 대한 실무 경험
# • 세일즈 및 파트너십 확장 전략 수립 능력
# • 뛰어난 커뮤니케이션 및 협상 능력
#
# points
# • 엔터테인먼트 또는 MD(머천다이징) 관련 경력
# • 팬덤 경제 및 IP비즈니스에 대한 이해
# • 다양한 IP와의 파트너십 성공 경험
# • 팝업스토어 운영, 계약 등 관련 업무경험 우대
#
# work_description
# • MD관련 사업성 검토 및 사업 전개, MD파트너십 계약 및 관리
# • 파트너사 협의를 통한 세일즈 확대 전략 수립 및 실행
# • 신규 비즈니스 모델(BM) 확장 제안, 시장 트렌드 분석 및 기회 발굴
#
#
#
#
# Metadata:
# {'career_type': 'EXPERIENCED', 'career_min': 3, 'career_max': 5, 'work_type': 'FULL_TIME', 'education_type': 'NO_PREFERENCE', 'workday_content': '주 5일제', 'info_url': 'https://www.wanted.co.kr/wd/247224'}

# %%
uuids = [str(uuid4()) for _ in range(len(documents))]
vector_store.add_documents(documents=documents, ids=uuids)

print(vector_store)
# Out:
# <langchain_community.vectorstores.faiss.FAISS object at 0x7f5189dcd6d0>

# %%
results = vector_store.similarity_search_with_score("프론트엔드 개발자", k=5)

for res, score in results:
    print(score)
    print(res.metadata)
    print(res.page_content)
    print("-"*100)
# Out:
# 0.9029131
# {'career_type': 'EXPERIENCED', 'career_min': 3, 'career_max': 3, 'work_type': 'FULL_TIME', 'education_type': 'NO_PREFERENCE', 'workday_content': '주 5일제', 'info_url': 'https://www.wanted.co.kr/wd/255411'}
# title
# 프론트엔드 개발자
#
# description
# • pre-A EduTech 스타트업 트루밸류에서 프론트엔드 개발자를 모집합니다.
# • 트루밸류는 이번 투자유치를 통해 본격적인 성장의 발판을 준비 중에 있으며 그 중 개발팀 빌딩은 새로운 성장 동력 확보에 있어 가장 핵심적인 퍼즐 조각으로 인지하고 있습니다.
# • 서로의 꿈을 응원하고 꿈을 이뤄가는 과정을 공유하는 Z세대를 위한 SNS 드림어필과 진로교육플랫폼 에버멘토의 iOS, Andrord, Web 개발 및 유지보수를 담당해줄 프론트엔드 개발자를 모집합니다.
#
# tasks
# • 기획자와 협업하여 플랫폼 설계, 구축, 운영
# • 확장성, 테스트 자동화가 가능하도록 아키텍쳐 설계 및 개선
# • React, React native 기반 웹, 앱 개발
# • RESTful 기반 API 연동
#
# requirements
# • 프론트엔드 개발 경력 3년 이상
# • HTML, CSS, JS 언어에 대한 깊은 이해
# • Next.js, react 기반의 웹서버 개발 경험 보유자
# • AWS 환경 구축/운영 경험이 있으신 분(ec2, nginx, ssl, https)
# • react native, expo 기반의 앱 개발 경험 보유자( 심사 및 배포 경험 필수)
# • 협업툴(Git, GitHub action) 및 빌드관리도구사용경험 보유자
# • Backend, DB 개발에 대한 지식보유자
#
# points
# • 특정 언어, 프레임워크에 구애 받지 않는 우수한 학습 능력이 있으신 분
# • 협업 및 문서 읽기/쓰기에 지장이 없는 영어 구사 능력이 있으신 분
# • 우수한 문서 커뮤니케이션 능력이 있으신 분
# • Git, Github 사용해 보신 분
# • Firebase 사용해 보신 분
# • REST API 연동해 보신 분
# • 클린 아키텍쳐에 관심있으신 분
# • 배포 자동화/테스트 자동화 관련 경험이 있으신 분
# • 이미지 처리 관련 분야의 지식이나 경험이 있으신 분
# • 스케일, 성능, 안정성, 비용을 최적화하여 개발하시는 분
#
# work_description
# • 기획자와 협업하여 플랫폼 설계, 구축, 운영
# • 확장성, 테스트 자동화가 가능하도록 아키텍쳐 설계 및 개선
# • React, React native 기반 웹, 앱 개발
# • RESTful 기반 API 연동
#
#
# ----------------------------------------------------------------------------------------------------
# 0.9616885
# {'career_type': 'UNTIL_HIRED', 'career_min': None, 'career_max': None, 'work_type': 'FULL_TIME', 'education_type': 'NO_PREFERENCE', 'workday_content': None, 'info_url': 'https://www.wanted.co.kr/wd/253175'}
# title
# 프론트엔드 개발자
#
# description
# We achieve innovation through IT technology
# 우리는 더 나은 세상을 위한 융복합 IT솔루션 기업 robot n com 입니다.
# 함께 성장하고 가치를 만들어 로봇앤컴의 도약에 힘을 실어줄 개발자를 모십니다.
#
# 이제까지 우리는,
# 30건이 넘는 특허 이노비즈 및 메인비즈 인증,
# 청년친화 강소기업, 직무발명보상 우수기업 등으로 기업 역량을 인정받았습니다.
#
# 현재 우리는,
# [디지털 의료 플랫폼] [월드와이드 통합 수리, 수선 플랫폼]으로
# 전국 네트워크,. 시스템 인프라 구축 솔루션 및 다수의 병원과 의료 전문 기관의
# 컴퓨터/IT 네트워크를 구축하고 유지, 보수하고있습니다.
#
# 앞으로 우리는,
# [월드와이드 유니콘 기업]으로 자리매김 하기 위한 도전을 이어나갑니다.
# 기존 탄탄한 SI를 기반으로 플랫폼 기업으로 나아가는 본격적인 시작을 눈 앞에 두고 있으며,
# 융복합 시대를 이끄는 IT 솔루션 기업이 될 것입니다.
#
# tasks
# 웹 기반 플랫폼의 프론트엔드 개발
#
# requirements
# • 주요 기술 스택
#   · 코어 : React, TypeScript, Next.js
#   · 상태 관리 : Redux
#   · 스타일링 : Tailwind, Scss
#   · 패키지 매니저 : npm
#   · 빌드 : Webpack
# • Git을 사용한 협업 및 코드 관리 경험
# • 변경에 유연한 아키텍처 및 모듈화된 코드 설계에
#   대한 이해와 적용 경험
# • UI/UX 트렌드에 관심이 많고 신기술에 대해 열린 자세
# • 팀 단위 협업 경험(Agile 방법론 경험자 우대)
# • 고성능, 대용량 시스템 개발 및 운영 경험을 보유하신 분
# • 차트, 그래프 등 데이터 시각화 경험
# • CI/CD 파이프라인 구축 및 유지 경험
#
# points
# • 리더 경험이 있으신 분
# • CRM, ERP 시스템 개발 경험
# • 전공자 우대
# • 하나의 서비스를 장기적으로 유지보수한 경험
# • 다양한 상태 관리 라이브러리 사용경험 (ex. Redux, Recoil)
# • API 통신 관련 라이브러리(Axios, GraphQL)경험
# • 테스트 자동화 도구(Jest, Cypress 등)를 활용한 경험
# • 클린코드 작성 및 리팩토링 경험
# • 다양한 브라우저 및 디바이스 대응 경험
# • ESBuild, SWC, Babel을 사용한 빌드 경험
#
# work_description
# 웹 기반 플랫폼의 프론트엔드 개발
#
#
# ----------------------------------------------------------------------------------------------------
# 0.9666416
# {'career_type': 'EXPERIENCED', 'career_min': 3, 'career_max': 3, 'work_type': 'FULL_TIME', 'education_type': 'NO_PREFERENCE', 'workday_content': '주 5일제', 'info_url': 'https://www.wanted.co.kr/wd/231537'}
# title
# 프론트엔드 개발자
#
# description
# LLM 솔루션 개발과 LLMOps 구축 담당 프론트 엔드 개발자
#
# tasks
# 1. 신규 생성형AI(LLM, LMM) 프론트 서비스 개발
# 2. 자사 서비스 프론트 서비스 유지 및 개선(리팩토링) 개발
#
# requirements
# 1. 프론트 엔드 개발 경력 3년 이상 또는 이에 준하는 능력을 보유하신 분
# 2. SPA 프레임워크 하나라도 프로젝트를 시작과 배포까지 완료 하신 경험이 있으신분(Angular, React, Vue.js)
# 3. 동료와 커뮤니케이션 하는데 문제 없으신 분
# 4. 새로운 기술에 대한 관심이 많고, 자기개발을 위해 노력하시는 분
#
# points
# 1. React, NextJs, Typescript 프로젝트으로 서비스 배포 경험이 있으신 분
# 2. Webpack으로 서비스 배포 경험이 있으신 분
# 3. Git 으로 소스 관리에 경험이 있으신 분
# 4. CI / CD 파이프라인을 통한 배포 경험이 있으신 분
# 5. 업무에 AI 서비스를 적극 활용하시는 분 / 백엔드 개발 경험 있으신분
#
# work_description
# 1. 신규 생성형AI(LLM, LMM) 프론트 서비스 개발
# 2. 자사 서비스 프론트 서비스 유지 및 개선(리팩토링) 개발
#
#
# ----------------------------------------------------------------------------------------------------
# 0.970425
# {'career_type': 'EXPERIENCED', 'career_min': 3, 'career_max': None, 'work_type': 'FULL_TIME', 'education_type': 'NO_PREFERENCE', 'workday_content': '주 5일제', 'info_url': 'https://www.wanted.co.kr/wd/250894'}
# title
# 프론트엔드 개발자
#
# description
# 부동산플래닛은 빅테이터 및 AI 기반 산업용 전문 프롭테크 기업입니다.
# 부동산 공간정보 및 빅테이터 분석 등을 통하여 다양한 데이터를 구축한 회사로 AI기술을 활용하여 전국 토지, 건물 부동산 추정가격을 제공하고 있으며, 상업용 부동산 투자, 임대, 관리, 매각까지 전 과정을 지원하는 부동산 종합 플랫폼을 구축해 나가고 있습니다.
# 또한, 데이터 기반의 자문 및 디지털 마케팅 역량을 바탕으로 매입/매각, 임대/임차 자문, 자산관리 서비스 등 풀스택 부동산 서비스를 제공하고 있습니다.
#
# tasks
# - 부동산 웹/앱 애플리케이션 Front-End 개발
# - Front-End 아키텍처 설계
#
# requirements
# - React 개발 경력 3년 이상
# - Redux 등 상태 관리 개발 경험자
# - REST API 서버 연동 개발 경험자
# - TypeScript를 사용한 개발 경험자
# - OpenLayers, leaflet 등 map 라이브러리 개발 경험자
# - webpack 등의 module bundler를 활용한 개발 경험자
#
# points
# - Next.js 개발 경험자
# - 커머스 플랫폼 관련 개발 경험자
# - Vanilla JS를 이용한 개발 경험자
# - ES6+, 웹표준에 대한 이해도 보유자
# - Figma를 통한 디자인 파트와의 협업 경험자
# - Git, SVN를 활용한 업무 관리 및 협업 경험자
# - 새로운 기술, 환경에 대한 거부감이 없는 개발자
# - 사용자 관점에서 서비스 개선에 능동적인 개발자
#
# work_description
# - 부동산 웹/앱 애플리케이션 Front-End 개발
# - Front-End 아키텍처 설계
#
#
# ----------------------------------------------------------------------------------------------------
# 0.98035085
# {'career_type': 'EXPERIENCED', 'career_min': 5, 'career_max': None, 'work_type': 'FULL_TIME', 'education_type': 'NO_PREFERENCE', 'workday_content': '주 5일제', 'info_url': 'https://www.wanted.co.kr/wd/243624'}
# title
# 프론트엔드 개발자 (5년 이상)
#
# description
# 저희 회사는 현재 스텔스 모드로 유능하고 성실한 초기 개발 팀원들을 모으고 있습니다.
#
# 개발 플랫폼 스타트업을 시작해 Y Combinator(W21)를 비롯한 글로벌 SaaS창업자들(Twilio, Datadog, Automattic, Unity 등)로 부터 280억원 투자를 받고 2023년에 Workday에 매각했습니다.
# 이 경험을 바탕으로 이번엔 AI 기술을 기반으로 글로벌 ERP 생태계를 disrupt하고자 합니다.
# 실리콘 밸리의 속도와 방식으로 글로벌한 기업으로 성장하는 과정을 함께 하고싶은 분들을 찾습니다.
#
# tasks
# • 초기 개발 팀원으로서 MVP개발에 적극적으로 참여하실수 있습니다.
# • 미국의 잠재고객들의 필요를 파악하고 문제를 해결하는데 중요한 역할을 할 수 있습니다.
#
# requirements
# • 글로벌한 문제를 찾고 해결책을 찾아가는데 열정이 있으신 분
# • Javascript, Typescript, Vue, React 등 클라이언트 사이드 프로그래밍/라이브러리 사용 경력
# • 데이터 시각화 라이브러리 사용(예: d3js, plot 등) 경험
# • RDBMS, NoSQL 및 분산 데이터베이스 이해 및 경험
# • 퍼블릭 또는 프라이빗 클라우드 컴퓨팅 솔루션 경험과 이해 (예: AWS, GCP 등)
# • 시스템 개발, 배포 및 유지보수 경력 5년 이상
# • 자신의 생각을 논리적으로 제시하고 설득할 수 있는 능력
# • 문제점에 대한 근본원인을 찾는 추론 능력
# • 오버/언더 엔지니어링을 이해하고 주어진 문제에 최선의 해결책을 찾는 능력
# • 스스로 문제를 도출하고 해결책도 제시할 수 있는 능력
# • 해외 출장 및 근무에 결격 사유 없으신 분
#
# points
# • 스타트업에서 Frontend engineer로 근무한 경험
# • ACM-ICPC, Google codejam, Facebook hackercup or Topcoder 등 Problem solving 대회 경험
# • Real world, large scale의 상용 시스템을 개발해보신 분
# • 개발조직 또는 프로젝트 리드 경험이 있는 분
# • 봉사활동 경험이 있으신 분
#
# work_description
# • 초기 개발 팀원으로서 MVP개발에 적극적으로 참여하실수 있습니다.
# • 미국의 잠재고객들의 필요를 파악하고 문제를 해결하는데 중요한 역할을 할 수 있습니다.
#
#
# ----------------------------------------------------------------------------------------------------
